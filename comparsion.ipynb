# %% [markdown]
# # Final Model - article

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Final Model - reproduced

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # Model A3.1. - article

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Model A3.1. - reproduced

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # Model A3.2. - article

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Model A3.2. - reproduced

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # Model A3.3. - article

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Model A3.3. - reproduced

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # Model A3.4. - article

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Model A3.4. - reproduced

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # Visualization - article

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Visualization - reproduced

# %% [markdown]
# ![image.png](attachment:image.png)
